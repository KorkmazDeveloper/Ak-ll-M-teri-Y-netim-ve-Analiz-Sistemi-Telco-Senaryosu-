# %%
# ==========================================
# PYTHON PROGRAMLAMA DÖNEM ÖDEVİ
# Akıllı Müşteri Yönetim ve Analiz Sistemi
# ==========================================

# Kütüphane Kullanımı
import random      # Rastgele sayı üretme
import math        # Matematik işlemleri
from datetime import datetime  # Tarih işlemleri

# ====================================================
# 1. KISIM : Veri Yapıları ve Temel Mantık
# ====================================================

# Değişken Tanımlama
ad_soyad = "Ahmet Yilmaz"
aylik_ucret = 650.75
sadakat_ayi = 30
aktif_mi = True

# Liste Kullanımı
hizmetler = [
    "Internet",
    "TV",
    "Telefon",
    "Mobil Hat",
    "Bulut Depolama"
]

# Sözlük Kullanımı
musteri = {
    "ad_soyad": ad_soyad,
    "aylik_ucret": aylik_ucret,
    "sadakat_ayi": sadakat_ayi,
    "aktif_mi": aktif_mi
}

print("Müşteri Bilgileri")
print(musteri)

# If-Else Kullanımı
if aylik_ucret > 500 or sadakat_ayi > 24:
    print("VIP Müşteri: İndirim Tanımla")
else:
    print("Standart Müşteri")

# String Operasyonları
buyuk_harf_isim = ad_soyad.upper()

# Random Kullanımı
customerID = "IST-2026-" + str(random.randint(1000, 9999))

print("Büyük Harf İsim:", buyuk_harf_isim)
print("Customer ID:", customerID)

# ====================================================
# 2. KISIM : Fonksiyonlar, Döngüler ve Kütüphaneler
# ====================================================

# Ana Liste Oluşturma
musteriler_listesi = [
    {"ad":"Ahmet","aylik_ucret":650,"sadakat_ayi":30,"aktif_mi":True},
    {"ad":"Ayşe","aylik_ucret":350,"sadakat_ayi":8,"aktif_mi":True},
    {"ad":"Mehmet","aylik_ucret":120,"sadakat_ayi":2,"aktif_mi":False},
    {"ad":"Zeynep","aylik_ucret":780,"sadakat_ayi":40,"aktif_mi":True},
    {"ad":"Ali","aylik_ucret":200,"sadakat_ayi":4,"aktif_mi":False}
]

# Fonksiyon Tanımlama
def tutar_hesapla(aylik_ucret):
    kdvli_tutar = aylik_ucret * 1.20
    return kdvli_tutar

print("\n===== FATURA RAPORU =====")

# Döngü Kullanımı
for musteri in musteriler_listesi:

    # Fonksiyon Çağırma
    kdvli_tutar = tutar_hesapla(musteri["aylik_ucret"])

    # Math Kullanımı
    yuvarlanmis_tutar = math.ceil(kdvli_tutar)

    print("--------------------")
    print("Müşteri:", musteri["ad"])
    print("Fatura:", yuvarlanmis_tutar, "TL")

    # Churn Analizi
    if musteri["sadakat_ayi"] < 6 or not musteri["aktif_mi"]:
        print("Durum: Churn Riski")
    else:
        print("Durum: Aktif Müşteri")

# Datetime Kullanımı
bugun = datetime.now()

print("\nRapor Tarihi:", bugun.strftime("%d/%m/%Y"))

# ====================================================
# SET KULLANIMI
# ====================================================

tum_hizmetler = [
    "Internet",
    "TV",
    "Telefon",
    "Internet",
    "Mobil Hat",
    "TV",
    "Bulut Depolama",
    "Internet"
]

benzersiz_hizmetler = set(tum_hizmetler)

print("\nBenzersiz Hizmetler:")
print(benzersiz_hizmetler)

# ====================================================
# SATIR SATIR KONU ETİKETLİ VERSİYON
# ====================================================

# Kütüphane Kullanımı
import random

# Kütüphane Kullanımı
import math

# Kütüphane Kullanımı
from datetime import datetime

# Değişken Tanımlama
ad = "Ahmet"

# Değişken Tanımlama
ucret = 500

# Fonksiyon Tanımlama
def hesapla(x):

    # Hesaplama İşlemi
    return x * 1.20

# Liste Kullanımı
liste = [100,200,300]

# Döngü Kullanımı
for eleman in liste:

    # Fonksiyon Çağırma
    sonuc = hesapla(eleman)

    # Math Kütüphanesi Kullanımı
    sonuc = math.ceil(sonuc)

    # Ekrana Yazdırma
    print(sonuc)

# Tarih Kütüphanesi Kullanımı
print(datetime.now())
# Out:
# Müşteri Bilgileri
# {'ad_soyad': 'Ahmet Yilmaz', 'aylik_ucret': 650.75, 'sadakat_ayi': 30, 'aktif_mi': True}
# VIP Müşteri: İndirim Tanımla
# Büyük Harf İsim: AHMET YILMAZ
# Customer ID: IST-2026-2227
#
# ===== FATURA RAPORU =====
# --------------------
# Müşteri: Ahmet
# Fatura: 780 TL
# Durum: Aktif Müşteri
# --------------------
# Müşteri: Ayşe
# Fatura: 420 TL
# Durum: Aktif Müşteri
# --------------------
# Müşteri: Mehmet
# Fatura: 144 TL
# Durum: Churn Riski
# --------------------
# Müşteri: Zeynep
# Fatura: 936 TL
# Durum: Aktif Müşteri
# --------------------
# Müşteri: Ali
# Fatura: 240 TL
# Durum: Churn Riski
#
# Rapor Tarihi: 06/06/2026
#
# Benzersiz Hizmetler:
# {'Bulut Depolama', 'Internet', 'Mobil Hat', 'Telefon', 'TV'}
# 120
# 240
# 360
# 2026-06-06 08:31:36.439672
